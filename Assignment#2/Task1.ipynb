# %%
import requests

def getLiveScore():
    print("Fetching live cricket scores...")

    try:
        with open('api.txt', 'r') as file:
            apiUrl = file.read()
    except:
        print("Error: Could not read API.")
        return
    try:
        response = requests.get(apiUrl)

        if response.status_code != 200:
            print(f"HTTP Error: {response.status_code} \n Raw response: {response.text}")
            return

        data = response.json()

        for key, value in data.items():
            if key != "data":
                print(f" {key}: {value}")
                      
        print("\n")

        if data.get("status") != "success":
            reason = data.get("API returned failure status")
            print(f"API Error: {reason}")
            return
        
        if "data" not in data or not data["data"]:
            print("No matches found")

        matchList = data["data"]
        print(f"Found {len(matchList)} matches.\n")

        for match in matchList:
            print(f"Match: {match.get('name', 'N/A')}")
            print(f"Status: {match.get('status', 'N/A')}")
            print(f"Venue: {match.get('venue', 'N/A')}")
            print(f"Date: {match.get('date', 'N/A')}")

            if "score" in match and match["score"]:
                for inning in match["score"]:
                    print(f" Inning: {inning.get('inning', 'N/A')}")
                    print(f" Runs:   {inning.get('r', 'N/A')}")
                    print(f" Wickets:{inning.get('w', 'N/A')}")
                    print(f" Overs:  {inning.get('o', 'N/A')}")
        
            else:
                print("No score available.")

            print("\n")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")

# %%
getLiveScore()
# Out:
# Fetching live cricket scores...
#  apikey: de638428-9c2a-479d-a412-07dbdc5073d8
#  status: success
#  info: {'hitsToday': 69, 'hitsUsed': 1, 'hitsLimit': 100, 'credits': 0, 'server': 14, 'offsetRows': 0, 'totalRows': 13196, 'queryTime': 158.322, 's': 0, 'cache': 0}
#
#
# Found 25 matches.
#
# Match: Nepal vs United States of America, 86th Match
# Status: United States of America won by 106 runs
# Venue: Dubai International Cricket Stadium, Dubai
# Date: 2025-10-26
#  Inning: United States of America Inning 1
#  Runs:   262
#  Wickets:6
#  Overs:  50
#  Inning: Nepal Inning 1
#  Runs:   156
#  Wickets:10
#  Overs:  39.1
#
#
# Match: Brazil vs Mexico, 3rd Match
# Status: Mexico won by 54 runs
# Venue: Sao Fernando Polo and Cricket Club, Seropedica
# Date: 2025-11-01
#  Inning: Mexico Inning 1
#  Runs:   179
#  Wickets:5
#  Overs:  20
#  Inning: Brazil Inning 1
#  Runs:   125
#  Wickets:9
#  Overs:  19.5
#
#
# Match: Brazil vs Panama, 2nd Match
# Status: No result
# Venue: Sao Fernando Polo and Cricket Club, Seropedica
# Date: 2025-10-31
#  Inning: Brazil Inning 1
#  Runs:   92
#  Wickets:10
#  Overs:  17
#
#
# Match: Panama vs Mexico, 1st Match
# Status: No result (due to rain)
# Venue: Sao Fernando Polo and Cricket Club, Seropedica
# Date: 2025-10-30
#  Inning: Panama Inning 1
#  Runs:   40
#  Wickets:6
#  Overs:  8
#
#
# Match: Thailand Women vs Papua New Guinea Women, 6th Match
# Status: Match starts at Nov 17, 06:30 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-17
# No score available.
#
#
# Match: Scotland Women vs Namibia Women, 5th Match
# Status: Match starts at Nov 17, 02:00 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-17
# No score available.
#
#
# Match: Thailand Women vs Scotland Women, 4th Match
# Status: Match starts at Nov 15, 06:30 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-15
# No score available.
#
#
# Match: Namibia Women vs Papua New Guinea Women, 3rd Match
# Status: Match starts at Nov 15, 02:00 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-15
# No score available.
#
#
# Match: Thailand Women vs Namibia Women, 2nd Match
# Status: Match starts at Nov 14, 06:30 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-14
# No score available.
#
#
# Match: Scotland Women vs Papua New Guinea Women, 1st Match
# Status: Match starts at Nov 14, 02:00 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-14
# No score available.
#
#
# Match: Papua New Guinea Women vs United Arab Emirates Women, 4th ODI
# Status: Papua New Guinea Women won by 78 runs
# Venue: Amini Park, Port Moresby
# Date: 2025-10-19
#  Inning: Papua New Guinea Women Inning 1
#  Runs:   210
#  Wickets:9
#  Overs:  50
#  Inning: United Arab Emirates Women Inning 1
#  Runs:   132
#  Wickets:10
#  Overs:  42.4
#
#
# Match: Uganda Women vs Canada Women, 5th T20I
# Status: Uganda Women won by 12 runs
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-26
#  Inning: Uganda Women Inning 1
#  Runs:   101
#  Wickets:4
#  Overs:  20
#  Inning: Canada Women Inning 1
#  Runs:   89
#  Wickets:10
#  Overs:  20
#
#
# Match: Uganda Women vs Canada Women, 4th T20I
# Status: Uganda Women won by 43 runs
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-24
#  Inning: uganda women Inning 1
#  Runs:   113
#  Wickets:4
#  Overs:  20
#  Inning: Uganda Women,Canada Women Inning 1
#  Runs:   70
#  Wickets:9
#  Overs:  20
#
#
# Match: Romania vs Austria, 4th T20I
# Status: Austria won by 42 runs
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-19
#  Inning: Austria Inning 1
#  Runs:   207
#  Wickets:6
#  Overs:  20
#  Inning: Romania Inning 1
#  Runs:   165
#  Wickets:10
#  Overs:  18.5
#
#
# Match: Romania vs Austria, 3rd T20I
# Status: Austria won by 7 wkts
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-19
#  Inning: Romania Inning 1
#  Runs:   157
#  Wickets:10
#  Overs:  20
#  Inning: Austria Inning 1
#  Runs:   163
#  Wickets:3
#  Overs:  16
#
#
# Match: Papua New Guinea Women vs United Arab Emirates Women, 3rd ODI
# Status: United Arab Emirates Women won by 160 runs
# Venue: Amini Park, Port Moresby
# Date: 2025-10-17
#  Inning: United Arab Emirates Women Inning 1
#  Runs:   193
#  Wickets:7
#  Overs:  50
#  Inning: Papua New Guinea Women Inning 1
#  Runs:   33
#  Wickets:10
#  Overs:  15.4
#
#
# Match: Uganda Women vs Canada Women, 3rd T20I
# Status: Uganda Women won by 18 runs
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-23
#  Inning: Uganda Women Inning 1
#  Runs:   100
#  Wickets:6
#  Overs:  20
#  Inning: Canada Women Inning 1
#  Runs:   82
#  Wickets:10
#  Overs:  18.3
#
#
# Match: Uganda Women vs Canada Women, 2nd T20I
# Status: Uganda Women won by 4 wkts
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-21
#  Inning: Canada Women Inning 1
#  Runs:   82
#  Wickets:6
#  Overs:  20
#  Inning: Uganda Women Inning 1
#  Runs:   83
#  Wickets:6
#  Overs:  19
#
#
# Match: Uganda Women vs Canada Women, 1st T20I
# Status: Uganda Women won by 7 wkts
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-20
#  Inning: Canada Women Inning 1
#  Runs:   67
#  Wickets:10
#  Overs:  19
#  Inning: Uganda Women Inning 1
#  Runs:   68
#  Wickets:3
#  Overs:  12
#
#
# Match: Papua New Guinea Women vs United Arab Emirates Women, 2nd ODI
# Status: Papua New Guinea Women won by 3 wkts
# Venue: Amini Park, Port Moresby
# Date: 2025-10-15
#  Inning: United Arab Emirates Women Inning 1
#  Runs:   143
#  Wickets:10
#  Overs:  45.4
#  Inning: Papua New Guinea Women Inning 1
#  Runs:   146
#  Wickets:7
#  Overs:  42.5
#
#
# Match: Papua New Guinea Women vs United Arab Emirates Women, 1st ODI
# Status: United Arab Emirates Women won by 5 wkts
# Venue: Amini Park, Port Moresby
# Date: 2025-10-12
#  Inning: Papua New Guinea Women Inning 1
#  Runs:   93
#  Wickets:10
#  Overs:  33.2
#  Inning: United Arab Emirates Women Inning 1
#  Runs:   97
#  Wickets:5
#  Overs:  33.1
#
#
# Match: Romania vs Austria, 2nd T20I
# Status: Romania won by 3 wkts
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-18
#  Inning: Austria Inning 1
#  Runs:   171
#  Wickets:10
#  Overs:  19.2
#  Inning: Romania Inning 1
#  Runs:   172
#  Wickets:7
#  Overs:  19.2
#
#
# Match: Romania vs Austria, 1st T20I
# Status: Austria won by 4 wkts
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-18
#  Inning: Romania Inning 1
#  Runs:   173
#  Wickets:9
#  Overs:  20
#  Inning: Austria Inning 1
#  Runs:   177
#  Wickets:6
#  Overs:  19
#
#
# Match: Pakistan vs South Africa, 3rd ODI
# Status: Pakistan won by 7 wkts
# Venue: Iqbal Stadium, Faisalabad
# Date: 2025-11-08
#  Inning: south africa Inning 1
#  Runs:   143
#  Wickets:10
#  Overs:  37.5
#  Inning: Pakistan,South Africa Inning 1
#  Runs:   144
#  Wickets:3
#  Overs:  25.1
#
#
# Match: Pakistan vs South Africa, 2nd ODI
# Status: South Africa won by 8 wkts
# Venue: Iqbal Stadium, Faisalabad
# Date: 2025-11-06
#  Inning: pakistan Inning 1
#  Runs:   269
#  Wickets:9
#  Overs:  50
#  Inning: Pakistan,South Africa Inning 1
#  Runs:   270
#  Wickets:2
#  Overs:  40.1
